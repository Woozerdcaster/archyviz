# %%
import ensurepip
ensurepip.bootstrap()
# Out:
# Looking in links: /var/folders/v7/7vfbdgg12c39wdwbk95gjb000000gn/T/tmpbkc5r4ch
# Processing /var/folders/v7/7vfbdgg12c39wdwbk95gjb000000gn/T/tmpbkc5r4ch/pip-25.3-py3-none-any.whl
# Installing collected packages: pip
# Successfully installed pip-25.3

# %%
import pip
pip.__version__
# Out:
# '25.3'

# %%
# %pip install openpyxl
# Out:
# Collecting openpyxl
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]1/2 [openpyxl]
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.getcwd()
os.listdir()
#stuff for getting file directories if I need it
# Out:
# ['02. Figure and Axes.ipynb',
#  'Untitled1.ipynb',
#  '.DS_Store',
#  '08_Text_Annotation.ipynb',
#  '04 Axes Components.ipynb',
#  'Untitled.ipynb',
#  'Hmk4_complete_jonas.ipynb',
#  '07 Plot.ipynb',
#  '01 uv_complete.ipynb',
#  'Wk1_Avi_cmplt.ipynb',
#  '02 Figure and Axes- Instructor.ipynb',
#  'Hmk3_prob1_jonas.ipynb',
#  '03 More Axes.ipynb',
#  'plotnine_tutorial.ipynb',
#  '05 Axes Components.ipynb',
#  '.ipynb_checkpoints',
#  'archy494data.xlsx',
#  '09 Artists.ipynb',
#  'Hmk2_jonas_complete.ipynb']

# %%
#but I uploaded the file instead
import openpyxl
from openpyxl import load_workbook

wb = load_workbook("archy494data.xlsx")

# %%
import pandas
#import xlrd
#but I uploaded the file instead

df = pandas.read_excel('archy494data.xlsx')

#print the column names
print (df.columns)

#get the values for a given column
values = df['Sub-Region'].values

#get a data frame with selected columns
#FORMAT = ['Col_1', 'Col_2', 'Col_3']
#df_selected = df[FORMAT]
# Out:
# Index(['Sub-Region', 'Adults', 'Subadults'], dtype='object')

# %%
#How do I access data from other tabs???
